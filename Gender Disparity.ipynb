# %%
import pandas as pd
df = pd.read_csv('survey_results_public.csv')

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 19             20  I am not primarily a developer, but I write co...       No
# 38             39                     I am a developer by profession      Yes
# 43             44                     I am a developer by profession      Yes
# 82             83                     I am a developer by profession      Yes
# 103           104                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88161       88711                     I am a developer by profession       No
# 88178       88728                     I am a developer by profession      Yes
# 88236       88786                     I am a developer by profession      Yes
# 88301       88853                     I am a developer by profession      Yes
# 88325       88878                     I am a developer by profession      Yes
#
# ...

# %%
df = df.dropna()
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 19             20  I am not primarily a developer, but I write co...       No
# 38             39                     I am a developer by profession      Yes
# 43             44                     I am a developer by profession      Yes
# 82             83                     I am a developer by profession      Yes
# 103           104                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88161       88711                     I am a developer by profession       No
# 88178       88728                     I am a developer by profession      Yes
# 88236       88786                     I am a developer by profession      Yes
# 88301       88853                     I am a developer by profession      Yes
# 88325       88878                     I am a developer by profession      Yes
#
# ...

# %%
a = df.corr()
a
# Out:
#                Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs  \
# Respondent       1.000000  -0.000012      -0.001973    -0.003616    0.002945
# CompTotal       -0.000012   1.000000       0.036799     0.027209    0.025619
# ConvertedComp   -0.001973   0.036799       1.000000     0.054998   -0.030514
# WorkWeekHrs     -0.003616   0.027209       0.054998     1.000000    0.039569
# CodeRevHrs       0.002945   0.025619      -0.030514     0.039569    1.000000
# Age              0.015098   0.005011       0.086446     0.043449   -0.036568
#
#                     Age
# Respondent     0.015098
# CompTotal      0.005011
# ConvertedComp  0.086446
# WorkWeekHrs    0.043449
# CodeRevHrs    -0.036568
# Age            1.000000

# %%
import seaborn as sn
import matplotlib.pyplot as plt

sn.heatmap(a, annot = True)
plt.show()

# %%
list(df.columns)
# Out:
# ['Respondent',
#  'MainBranch',
#  'Hobbyist',
#  'OpenSourcer',
#  'OpenSource',
#  'Employment',
#  'Country',
#  'Student',
#  'EdLevel',
#  'UndergradMajor',
#  'EduOther',
#  'OrgSize',
#  'DevType',
#  'YearsCode',
#  'Age1stCode',
#  'YearsCodePro',
#  'CareerSat',
#  'JobSat',
#  'MgrIdiot',
#  'MgrMoney',
#  'MgrWant',
#  'JobSeek',
#  'LastHireDate',
#  'LastInt',
#  'FizzBuzz',
#  'JobFactors',
#  'ResumeUpdate',
#  'CurrencySymbol',
#  'CurrencyDesc',
#  'CompTotal',
#  'CompFreq',
#  'ConvertedComp',
#  'WorkWeekHrs',
#  'WorkPlan',
#  'WorkChallenge',
#  'WorkRemote',
#  'WorkLoc',
#  'ImpSyn',
#  'CodeRev',
#  'CodeRevHrs',
#  'UnitTests',
#  'PurchaseHow',
#  'PurchaseWhat',
#  'LanguageWorkedWith',
#  'LanguageDesireNextYear',
#  'DatabaseWorkedWith',
#  'DatabaseDesireNextYear',
#  'PlatformWorkedWith',
#  'PlatformDesireNextYear',
#  'WebFrameWorkedWith',
#  'WebFrameDesireNextYear',
#  'MiscTechWorkedWith',
#  'MiscTechDesireNextYear',
#  'DevEnviron',
# ...

# %%
df.plot.scatter(x = 'Age1stCode', y = 'Gender', figsize = (20,10))
plt.show()

# %%
df.plot.hexbin(x = 'Gender', y = 'CompTotal', gridsize = 30, figsize = (27,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-8a3f6bde8b08> in <module>
# ----> 1 df.plot.hexbin(x = 'Gender', y = 'CompTotal', gridsize = 30, figsize = (27,10))
#       2 plt.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in hexbin(self, x, y, C, reduce_C_function, gridsize, **kwargs)
#    1586             kwargs["gridsize"] = gridsize
#    1587
# -> 1588         return self(kind="hexbin", x=x, y=y, C=C, **kwargs)
#    1589
#    1590
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     790         if kind in self._dataframe_kinds:
#     791             if isinstance(data, ABCDataFrame):
# --> 792                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     793             else:
# ...

# %%
df.plot.line(x = 'Ethnicity', y = 'Age1stCode', figsize = (20,10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-945188404679> in <module>
# ----> 1 df.plot.line(x = 'Ethnicity', y = 'Age1stCode', figsize = (20,10))
#       2 plt.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in line(self, x, y, **kwargs)
#     916             >>> lines = df.plot.line(x='pig', y='horse')
#     917         """
# --> 918         return self(kind="line", x=x, y=y, **kwargs)
#     919
#     920     def bar(self, x=None, y=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ...

# %%
from matplotlib.pyplot import figure
b = sn.lineplot(data=df, x="Gender", y="ConvertedComp")
b.figure.set_size_inches(23,7)

# %%
gender_dev = df.groupby(['Gender', 'DevType'], as_index = False).agg('mean')
gender_dev['DevType'] == 'Developer, full-stack'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1134    False
# 1135    False
# 1136    False
# 1137    False
# 1138    False
# Name: DevType, Length: 1139, dtype: bool

# %%
df1[df1['DevType'].str.contains('Developer')].sort_values('DevType')
# Out:
#      Gender                                            DevType  Respondent  \
# 2       Man  Academic researcher;Data or business analyst;D...     17453.0
# 3       Man  Academic researcher;Data or business analyst;D...      5443.0
# 4       Man  Academic researcher;Data or business analyst;D...       900.0
# 5       Man  Academic researcher;Data or business analyst;D...     52336.0
# 6       Man  Academic researcher;Data or business analyst;D...     65625.0
# ...     ...                                                ...         ...
# 1056    Man                   Developer, mobile;Engineer, data     37667.0
# 1057    Man                  Developer, mobile;Product manager     70955.5
# 1058    Man  Developer, mobile;Product manager;System admin...     83394.5
# 1059    Man                          Developer, mobile;Student     17569.0
# 1060    Man             Developer, mobile;System administrator     16581.0
#
#       CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs        Age
# ...

# %%
df1 = df.groupby(['DevType'], as_index = False).agg('count')
df1.sort_values('Respondent', ascending = False)
# Out:
#                                                 DevType  Respondent  \
# 1033                              Developer, full-stack         584
# 688                                 Developer, back-end         172
# 854   Developer, back-end;Developer, front-end;Devel...         163
# 923           Developer, back-end;Developer, full-stack         137
# 1013         Developer, front-end;Developer, full-stack          66
# ...                                                 ...         ...
# 379   Data scientist or machine learning specialist;...           1
# 381   Data scientist or machine learning specialist;...           1
# 382   Data scientist or machine learning specialist;...           1
# 384   Data scientist or machine learning specialist;...           1
# 545   Database administrator;Developer, back-end;Dev...           1
#
#       MainBranch  Hobbyist  OpenSourcer  OpenSource  Employment  Country  \
# 1033         584       584          584         584         584      584
# ...

# %%
from matplotlib.pyplot import figure


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(df1['Gender'],df1['DevType'])
fig.set_size_inches(23, 16, forward=True)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-0c87d3cddd62> in <module>
#       8
#       9
# ---> 10 plt.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
# ...

# %%
gender_dev[gender_dev['DevType'] == 'Developer, back-end']
# Out:
#      Gender              DevType    Respondent      CompTotal  ConvertedComp  \
# 669     Man  Developer, back-end  44071.615854  306947.091463    94518.20122
# 1109  Woman  Developer, back-end  47507.500000   64750.000000    53947.75000
#
#       WorkWeekHrs  CodeRevHrs        Age
# 669     40.481707    4.478659  30.506098
# 1109    39.000000    5.125000  32.875000

# %%
143874.909091/150836.478648
# Out:
# 0.9538469101148545

# %%
41.108541/39.840909
# Out:
# 1.031817346336149

# %%
gender_dev[gender_dev['Gender']== 'Woman']
# Out:
#      Gender                                            DevType    Respondent  \
# 1080  Woman  Academic researcher;Data scientist or machine ...  47472.000000
# 1081  Woman            Academic researcher;Developer, back-end  74572.000000
# 1082  Woman  Academic researcher;Developer, back-end;Develo...  19699.000000
# 1083  Woman  Academic researcher;Developer, embedded applic...  59676.000000
# 1084  Woman                           Data or business analyst   7331.000000
# 1085  Woman  Data or business analyst;Data scientist or mac...  76263.000000
# 1086  Woman  Data or business analyst;Database administrato...  82911.000000
# 1087  Woman  Data or business analyst;Database administrato...  58180.000000
# 1088  Woman  Data or business analyst;Designer;Developer, f...  83438.000000
# 1089  Woman  Data or business analyst;Developer, back-end;D...  31840.000000
# 1090  Woman      Data scientist or machine learning specialist  48844.000000
# ...

# %%
df[df['Gender'] == 'Woman']
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 540           542  I am a developer by profession      Yes
# 2294         2302  I am a developer by profession      Yes
# 2640         2649  I am a developer by profession      Yes
# 2948         2961  I am a developer by profession      Yes
# 4041         4057  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 85750       86285  I am a developer by profession       No
# 86020       86555  I am a developer by profession      Yes
# 86984       87526  I am a developer by profession       No
# 87158       87700  I am a developer by profession      Yes
# 87424       87967  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 540                              Less than once per year
# 2294                                               Never
# 2640   Less than once a month but more than once per ...
# ...

# %%
A = df[(df['Gender'] == 'Woman') & (df['DevType'] == 'Developer, full-stack')]
len(A)
# Out:
# 22
